# %% [markdown]
# # Vast Notebook for Diarization

# %%
import time
load_ts = time.time()

# %%
# install ffmpeg
# !conda install -y -q ffmpeg

# %%
# optional: confirm that ffmpeg is installed
# ! ffmpeg

# %%
# !pip install --user jiwer
# !pip install --user openai-whisper

# %%
# %pip install git+https://github.com/m-bain/whisperx.git

# %%
# !pip install pyannote.audio==3.0.1
# !pip uninstall onnxruntime
# !pip install --force-reinstall onnxruntime-gpu

# %%
HUGGINGFACE_TOKEN = ""

# %%
import gc
import json
import os
import whisperx
import gc 
from whisperx import load_align_model, align
from whisperx.diarize import DiarizationPipeline, assign_word_speakers

# %%
load_te = time.time()
load_duration = (load_te-load_ts) / 60.0
load_duration = float(f"{load_duration:.2f}")
print(f"load duration: {load_duration} min")
# Out:
# load duration: 10.21 min

# %%
# mp3_file = "./2016_07_15.mp3"
# print(f"mp3_file exists: {os.path.exists(mp3_file)}")

root_dir = "/workspace"
print(f"root dir exists:\t{os.path.exists(root_dir)}")
out_dir = os.path.join(root_dir, "transcripts")
podcast_dir = os.path.join(root_dir, "podcasts")

print(f"podcast dir exists:\t{os.path.exists(podcast_dir)}")
print(f"out dir exists:\t{os.path.exists(out_dir)}")

mp3_files = [os.path.join(podcast_dir, x) for x in os.listdir(podcast_dir) if x.endswith(".mp3")]
print(f"mp3_files: {mp3_files}")
# Out:
# root dir exists:	True
# podcast dir exists:	True
# out dir exists:	True
# mp3_files: ['/workspace/podcasts/2023_09_08.mp3', '/workspace/podcasts/2023_09_15.mp3', '/workspace/podcasts/2023_09_22.mp3']

# %%
def timeit(method):
    def timed(*args, **kw):
        ts = time.time()
        result = method(*args, **kw)
        te = time.time()
        duration = (te-ts) / 60.0
        duration = float(f"{duration:.2f}")
        print(f"{method.__name__} running time: {duration} min ")
        return result
    return timed

# %%
# %%time
device = "cuda" 
audio_file = mp3_files[0]
batch_size = 16 # reduce if low on GPU mem
compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)
# Out:
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 9.3 µs

# %%
audio_file
# Out:
# '/workspace/podcasts/2023_09_08.mp3'

# %%
# STEP 1 ------------------------------
# 1. Transcribe with original whisper (batched)
model = whisperx.load_model("medium", device, compute_type=compute_type, language="en")
# model = whisper.load_model("medium")

audio = whisperx.load_audio(audio_file)
result = model.transcribe(audio, batch_size=batch_size)
result = model.transcribe(audio, batch_size=batch_size, language="en")
print(result["segments"]) # before alignment
# Out:
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.1.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/whisperx-vad-segmentation.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.0. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.0.0. Bad things might happen unless you revert torch to 1.x.
# [{'text': ' Jeep Adventure Days is going on now. Hurry in for great deals on a great selection of Jeep brand vehicles. And right now, get 10% below MSRP for an average of $6,960 under MSRP on the purchase of a 2023 Jeep Wrangler 4xe. Not compatible with lease offers or with any other consumer incentive offers, $6,960 average based on 10% below average MSRP from all 2023 Wrangler 4xe models in dealer stock. Residency restrictions apply. Take retail delivery from dealer stock by 1031. Jeep is a registered trademark.', 'start': 0.503, 'end': 30.282}, {'text': " You clap better than anyone. I know, but I once did... No one normally gets to hear your clap, but we always start each recording with a clap, so that's Mark doing a clap, and my clap is slightly more feeble. I once interviewed Martin Scorsese, and it was about the re-release, a reissue of Peeping Tom.", 'start': 39.138, 'end': 59.77}, {'text': " And there was two cameras so it needed a clap. And the person who was directing the thing said, can someone give us a clap? And I went to do it and Mark Scorsese said, I've got this. So Scorsese in the room, you volunteered the clap.", 'start': 59.77, 'end': 78.404}, {'text': " Remind me who you are and does he do clap? Did I was a Scorsese clap? Notably noticeably better. Here's what it was He almost didn't like when I did it just then I kind of quite theatrically raised my hands above my head You know hands in the air like you just don't care what he did was he had his hands in his lap and he just went it and it was", 'start': 78.404, 'end': 100.077}, {'text': " It was like, okay, because he knew that the shot had his hands in them. So he just didn't have to do any theatrics at all. He just literally almost did it like that. It was like, yeah, just getting on with this. Are there any other clap stories that you have? No, that's pretty much it.", 'start': 100.52, 'end': 116.852}, {'text': " There is a story about end slating, which is that some directors don't do, you know the clapperboard thing. The old TV show, yes. No, there are people that make films now spinning in their grave going, come on, that's not what it's called. When you do the clapperboard, there's some directors do it at the end of a scene rather than the beginning of a scene, because when you go action, clap, it's sort of, you know, everything springs into life. And some directors, I have heard say, yeah, I don't do that. I do it at the end of the scene because I want the thing to just kind of begin", 'start': 118.097, 'end': 148.08}, {'text': " organically. The way this podcast does. The way this podcast does. Hello. I have been here, but you've been away. So it's just one of those things where when you've been here, I've been away. That's not true. I've only been away for three weeks, but because it didn't coincide with your sort of various world tour important gigs that you were doing. This just isn't true. How was your safari by the way? Oh, it was fabulous. What was the greatest thing, the very best thing that you saw? On the very last night", 'start': 148.08, 'end': 176.084}, {'text': " This is going to sound so naff. On the very last night, as the sun was going down, we were driving back and there's a lioness that they hadn't seen for a long time. This is Cornwall, yeah? This is Cornwall, yeah. And as we were driving back, the lioness came out of the thing and the three cubs which they hadn't seen and which they thought might not have", 'start': 176.084, 'end': 197.654}, {'text': " I've got a video, of course I've got a video. You know the videos that you keep showing me of Grandchild 1? Yes. I now have the video of the Three Lion Cubs. I've got so many new ones to show. Great, because it's been a long time. Presumably Grandchild 1 is now 12. And that's in South Africa. It's a wonderful place.", 'start': 197.654, 'end': 219.582}, {'text': " This is terrible because I don't generally do holidays. So it's the first time in a very long time that I've just don ...

# %%
# STEP 2 ------------------------------
# 2. Align whisper output
model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)
result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)

print(result["segments"]) # after alignment
# Out:
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960_asr_ls960.pth" to /root/.cache/torch/hub/checkpoints/wav2vec2_fairseq_base_ls960_asr_ls960.pth
# 100%|██████████| 360M/360M [00:06<00:00, 54.2MB/s]
# [{'start': 0.543, 'end': 1.984, 'text': ' Jeep Adventure Days is going on now.', 'words': [{'word': 'Jeep', 'start': 0.543, 'end': 0.723, 'score': 0.576}, {'word': 'Adventure', 'start': 0.763, 'end': 1.083, 'score': 0.937}, {'word': 'Days', 'start': 1.103, 'end': 1.283, 'score': 0.65}, {'word': 'is', 'start': 1.344, 'end': 1.384, 'score': 0.996}, {'word': 'going', 'start': 1.424, 'end': 1.624, 'score': 0.886}, {'word': 'on', 'start': 1.684, 'end': 1.764, 'score': 0.8}, {'word': 'now.', 'start': 1.824, 'end': 1.984, 'score': 0.926}]}, {'start': 2.104, 'end': 4.866, 'text': 'Hurry in for great deals on a great selection of Jeep brand vehicles.', 'words': [{'word': 'Hurry', 'start': 2.104, 'end': 2.304, 'score': 0.971}, {'word': 'in', 'start': 2.324, 'end': 2.384, 'score': 0.887}, {'word': 'for', 'start': 2.424, 'end': 2.524, 'score': 0.943}, {'word': 'great', 'start': 2.564, 'end': 2.744, 'score': 0.752}, {'word': 'deals', 'start': 2.784, 'end': 3.005, 'score': 0.868}, {'word': 'on', 'start': 3.045, 'end': 3.125, 'score': 0.784}, {'word': 'a', 'start': 3.145, 'end': 3.185, 'score': 0.492}, {'word': 'great', 'start': 3.225, 'end': 3.425, 'score': 0.82}, {'word': 'selection', 'start': 3.445, 'end': 3.805, 'score': 0.811}, {'word': 'of', 'start': 3.825, 'end': 3.865, 'score': 0.988}, {'word': 'Jeep', 'start': 3.925, 'end': 4.105, 'score': 0.438}, {'word': 'brand', 'start': 4.165, 'end': 4.405, 'score': 0.628}, {'word': 'vehicles.', 'start': 4.426, 'end': 4.866, 'score': 0.712}]}, {'start': 5.026, 'end': 13.611, 'text': 'And right now, get 10% below MSRP for an average of $6,960 under MSRP on the purchase of a 2023 Jeep Wrangler 4xe.', 'words': [{'word': 'And', 'start': 5.026, 'end': 5.086, 'score': 0.994}, {'word': 'right', 'start': 5.146, 'end': 5.286, 'score': 0.858}, {'word': 'now,', 'start': 5.326, 'end': 5.466, 'score': 0.915}, {'word': 'get', 'start': 5.526, 'end': 6.127, 'score': 0.619}, {'word': '10%'}, {'word': 'below', 'start': 6.167, 'end': 6.487, 'score': 0.865}, {'word': 'MSRP', 'start': 6.627, 'end': 7.247, 'score': 0.712}, {'word': 'for', 'start': 7.347, 'end': 7.447, 'score': 0.789}, {'word': 'an', 'start': 7.467, 'end': 7.527, 'score': 0.695}, {'word': 'average', 'start': 7.668, 'end': 7.968, 'score': 0.845}, {'word': 'of', 'start': 8.008, 'end': 8.068, 'score': 0.754}, {'word': '$6,960'}, {'word': 'under', 'start': 8.548, 'end': 9.929, 'score': 0.367}, {'word': 'MSRP', 'start': 10.029, 'end': 10.609, 'score': 0.755}, {'word': 'on', 'start': 10.73, 'end': 10.79, 'score': 0.954}, {'word': 'the', 'start': 10.81, 'end': 10.89, 'score': 0.805}, {'word': 'purchase', 'start': 10.93, 'end': 11.23, 'score': 0.81}, {'word': 'of', 'start': 11.25, 'end': 11.31, 'score': 0.747}, {'word': 'a', 'start': 11.35, 'end': 11.37, 'score': 0.707}, {'word': '2023'}, {'word': 'Jeep', 'start': 11.43, 'end': 11.69, 'score': 0.558}, {'word': 'Wrangler', 'start': 11.77, 'end': 12.911, 'score': 0.7}, {'word': '4xe.', 'start': 13.351, 'end': 13.611, 'score': 0.697}]}, {'start': 13.791, 'end': 24.899, 'text': 'Not compatible with lease offers or with any other consumer incentive offers, $6,960 average based on 10% below average MSRP from all 2023 Wrangler 4xe models in dealer stock.', 'words': [{'word': 'Not', 'start': 13.791, 'end': 13.932, 'score': 0.814}, {'word': 'compatible', 'start': 13.972, 'end': 14.412, 'score': 0.848}, {'word': 'with', 'start': 14.432, 'end': 14.512, 'score': 0.737}, {'word': 'lease', 'start': 14.572, 'end': 14.792, 'score': 0.449}, {'word': 'offers', 'start': 14.832, 'end': 15.092, 'score': 0.823}, {'word': 'or', 'start': 15.232, 'end': 15.312, 'score': 0.833}, {'word': 'with', 'start': 15.352, 'end': 15.473, 'score': 0.98}, {'word': 'any', 'start': 15.593, 'end': 15.713, 'score': 0.832}, {'word': 'other', 'start': 15.753, 'end': 15.913, 'score': 0.777}, {'word': 'consumer', 'start': 15.953, 'end': 16.313, 'score': 0.972}, {'word': 'incentive', 'start': 16.333, 'end': 16.713, 'score': 0.475}, {'word': 'offers,', 'sta ...

# %%
# STEP 3 ------------------------------
# 3. Assign speaker labels
diarize_model = whisperx.DiarizationPipeline(use_auth_token=HUGGINGFACE_TOKEN, device=device)

# add min/max number of speakers if known
# diarize_segments = diarize_model(audio)
diarize_segments = diarize_model(audio, min_speakers=2)
# diarize_model(audio, min_speakers=min_speakers, max_speakers=max_speakers)

result2 = whisperx.assign_word_speakers(diarize_segments, result)
# print(diarize_segments)

print(f'Speakers: {list(set([item["speaker"] for item in result2["segments"]]))}')
print(result2["segments"]) # segments are now assigned speaker IDs
# Out:
# Speakers: ['SPEAKER_15', 'SPEAKER_10', 'SPEAKER_18', 'SPEAKER_17', 'SPEAKER_05', 'SPEAKER_04', 'SPEAKER_20', 'SPEAKER_13', 'SPEAKER_09', 'SPEAKER_06', 'SPEAKER_01', 'SPEAKER_16', 'SPEAKER_14', 'SPEAKER_11', 'SPEAKER_03', 'SPEAKER_02', 'SPEAKER_00', 'SPEAKER_08', 'SPEAKER_12', 'SPEAKER_07', 'SPEAKER_19']
# [{'start': 0.543, 'end': 1.984, 'text': ' Jeep Adventure Days is going on now.', 'words': [{'word': 'Jeep', 'start': 0.543, 'end': 0.723, 'score': 0.576, 'speaker': 'SPEAKER_15'}, {'word': 'Adventure', 'start': 0.763, 'end': 1.083, 'score': 0.937, 'speaker': 'SPEAKER_15'}, {'word': 'Days', 'start': 1.103, 'end': 1.283, 'score': 0.65, 'speaker': 'SPEAKER_15'}, {'word': 'is', 'start': 1.344, 'end': 1.384, 'score': 0.996, 'speaker': 'SPEAKER_15'}, {'word': 'going', 'start': 1.424, 'end': 1.624, 'score': 0.886, 'speaker': 'SPEAKER_15'}, {'word': 'on', 'start': 1.684, 'end': 1.764, 'score': 0.8, 'speaker': 'SPEAKER_15'}, {'word': 'now.', 'start': 1.824, 'end': 1.984, 'score': 0.926, 'speaker': 'SPEAKER_15'}], 'speaker': 'SPEAKER_15'}, {'start': 2.104, 'end': 4.866, 'text': 'Hurry in for great deals on a great selection of Jeep brand vehicles.', 'words': [{'word': 'Hurry', 'start': 2.104, 'end': 2.304, 'score': 0.971, 'speaker': 'SPEAKER_15'}, {'word': 'in', 'start': 2.324, 'end': 2.384, 'score': 0.887, 'speaker': 'SPEAKER_15'}, {'word': 'for', 'start': 2.424, 'end': 2.524, 'score': 0.943, 'speaker': 'SPEAKER_15'}, {'word': 'great', 'start': 2.564, 'end': 2.744, 'score': 0.752, 'speaker': 'SPEAKER_15'}, {'word': 'deals', 'start': 2.784, 'end': 3.005, 'score': 0.868, 'speaker': 'SPEAKER_15'}, {'word': 'on', 'start': 3.045, 'end': 3.125, 'score': 0.784, 'speaker': 'SPEAKER_15'}, {'word': 'a', 'start': 3.145, 'end': 3.185, 'score': 0.492, 'speaker': 'SPEAKER_15'}, {'word': 'great', 'start': 3.225, 'end': 3.425, 'score': 0.82, 'speaker': 'SPEAKER_15'}, {'word': 'selection', 'start': 3.445, 'end': 3.805, 'score': 0.811, 'speaker': 'SPEAKER_15'}, {'word': 'of', 'start': 3.825, 'end': 3.865, 'score': 0.988, 'speaker': 'SPEAKER_15'}, {'word': 'Jeep', 'start': 3.925, 'end': 4.105, 'score': 0.438, 'speaker': 'SPEAKER_15'}, {'word': 'brand', 'start': 4.165, 'end': 4.405, 'score': 0.628, 'speaker': 'SPEAKER_15'}, {'word': 'vehicles.', 'start': 4.426, 'end': 4.866, 'score': 0.712, 'speaker': 'SPEAKER_15'}], 'speaker': 'SPEAKER_15'}, {'start': 5.026, 'end': 13.611, 'text': 'And right now, get 10% below MSRP for an average of $6,960 under MSRP on the purchase of a 2023 Jeep Wrangler 4xe.', 'words': [{'word': 'And', 'start': 5.026, 'end': 5.086, 'score': 0.994, 'speaker': 'SPEAKER_15'}, {'word': 'right', 'start': 5.146, 'end': 5.286, 'score': 0.858, 'speaker': 'SPEAKER_15'}, {'word': 'now,', 'start': 5.326, 'end': 5.466, 'score': 0.915, 'speaker': 'SPEAKER_15'}, {'word': 'get', 'start': 5.526, 'end': 6.127, 'score': 0.619, 'speaker': 'SPEAKER_15'}, {'word': '10%'}, {'word': 'below', 'start': 6.167, 'end': 6.487, 'score': 0.865, 'speaker': 'SPEAKER_15'}, {'word': 'MSRP', 'start': 6.627, 'end': 7.247, 'score': 0.712, 'speaker': 'SPEAKER_15'}, {'word': 'for', 'start': 7.347, 'end': 7.447, 'score': 0.789, 'speaker': 'SPEAKER_15'}, {'word': 'an', 'start': 7.467, 'end': 7.527, 'score': 0.695, 'speaker': 'SPEAKER_15'}, {'word': 'average', 'start': 7.668, 'end': 7.968, 'score': 0.845, 'speaker': 'SPEAKER_15'}, {'word': 'of', 'start': 8.008, 'end': 8.068, 'score': 0.754, 'speaker': 'SPEAKER_15'}, {'word': '$6,960'}, {'word': 'under', 'start': 8.548, 'end': 9.929, 'score': 0.367, 'speaker': 'SPEAKER_15'}, {'word': 'MSRP', 'start': 10.029, 'end': 10.609, 'score': 0.755, 'speaker': 'SPEAKER_15'}, {'word': 'on', 'start': 10.73, 'end': 10.79, 'score': 0.954, 'speaker': 'SPEAKER_15'}, {'word': 'the', 'start': 10.81, 'end': 10.89, 'score': 0.805, 'speaker': 'SPEAKER_15'}, {'word': 'purchase', 'start': 10.93, 'end': 11.23, 'score': 0.81, 'speaker': 'SPEAKER_15'}, {'word': 'of', 'start': 11.25, 'end': 11.31, 'score': 0.747, 'speaker': 'SPEAKER_15'}, {'word': 'a', 'start': 11.35, 'end': 11.37, 'score': 0.707, 'speaker': 'SPEAKER_15'}, {'word': '2023'}, {'word': 'Jeep', 'start': 11.43, 'end': 11.69, 'score': 0.558, 'speaker': 'SPEAKER_15'}, {'word': 'Wrangler', 'start': 11.77, 'end': 12.911, 'score': 0.7, 'speaker': 'SPEAKER_15'}, {'word': '4xe.', 'start': 13.351, 'en ...

# %%
import json

# %%
@timeit
def process_audio_file(audio_file):
    print(f"processing audio file: {audio_file}")
    # 1. Transcribe with original whisper (batched)
    model = whisperx.load_model("medium", device, compute_type=compute_type, language="en")
    audio = whisperx.load_audio(audio_file)
    result = model.transcribe(audio, batch_size=batch_size, language="en")
    # 2. Align whisper output
    model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)
    result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)
    # 3. Assign speaker labels
    diarize_model = whisperx.DiarizationPipeline(use_auth_token="HUGGINGFACE_TOKEN", device=device)
    diarize_segments = diarize_model(audio, min_speakers=2)
    # diarize_model(audio, min_speakers=min_speakers, max_speakers=max_speakers)

    result2 = whisperx.assign_word_speakers(diarize_segments, result)
    # print(diarize_segments)

    # print(f'Speakers: {list(set([item["speaker"] for item in result2["segments"]]))}')
    # print(result2["segments"]) # segments are now assigned speaker IDs
    return result2

# %%
def list_to_text(result):
    segments = result["segments"]
    return json.dumps(segments)
    
def save_transcript(path, data):
    with open(path, "w") as fo:
        fo.write(data)

# %%
# mp3_files = [x for x in os.listdir(podcast_dir) if x.endswith(".mp3")]
# mp3_file = mp3_files[0]
# mp3_file_path = os.path.join(podcast_dir, mp3_file) 
# # print(mp3_file_path)
# result = process_audio_file(mp3_file_path)
# transcript = list_to_text(result)
# name = mp3_file.replace(".mp3", "")
# path = os.path.join(out_dir, name)
# print(f"saving transcript of {name}...")
# save_transcript(path, transcript)
# Out:
# processing audio file: /workspace/podcasts/2023_09_08.mp3
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.1.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/whisperx-vad-segmentation.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.0. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.0.0. Bad things might happen unless you revert torch to 1.x.
# process_audio_file running time: 3.62 min
# saving transcript of 2023_09_08...

# %%
mp3_files = [x for x in os.listdir(podcast_dir) if x.endswith(".mp3")]

for mp3_file in mp3_files:
    print(f"processing mp3_file: {mp3_file} ...")
    mp3_file_path = os.path.join(podcast_dir, mp3_file) 
    result = process_audio_file(mp3_file)
    transcript = list_to_text(result)
    name = mp3_file.replace(".mp3", ".jsonl")
    path = os.path.join(out_dir, name)
    print(f"saving transcript of {name}...")
    save_transcript(path, transcript)
